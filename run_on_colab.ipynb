# %% [markdown]
# # HW3: Run on Google Colab
#
# Runs `hw3.py` directly—same script as local. Colab is just faster.
#
# **Steps:**
# 1. Clone/upload files, install deps, run `python hw3.py ...`
# 2. Download results when done
#
# **Tip:** Runtime → Change runtime type → T4 GPU (faster model inference)

# %%
# Option A: Clone from GitHub
# !git clone https://github.com/DhruvaVedula/490hw3.git
# %cd 490hw3

# Option B: If you uploaded a zip, uncomment:
# !unzip -o 490hw3.zip && cd 490hw3

# %%
# Install dependencies (Colab has PyTorch pre-installed)
# !pip install -q datasets transformers stanza pandas tqdm

# Pin transformers for PyTorch 2.2 compatibility (Colab may have newer torch)
# !pip install -q 'transformers>=4.30.0,<4.50.0'

# %%
# Run hw3.py (same as local)
# !python hw3.py --sample_size 15000 --output_dir . --workers 4

# %%
# Download results to your computer
from google.colab import files

for f in ['data.jsonl', 'perf.csv', 'complex.csv']:
    try:
        files.download(f)
        print(f'Downloaded {f}')
    except Exception as e:
        print(f'Could not download {f}: {e}')
